# %% [markdown]
# Esse notebook foi utilizado para verificar os dados do experimento
#
#
# LightSportHours: O quanto tempo no dia você fez exercicios leves? (1 -> <1hr; 2 -> 1-2hrs, 3 -> 2-4hrs,  4 -> <4hrs)
#
#
# ModSportHours: O quanto tempo no dia você fez exercicios moderados? (1 -> <1hr; 2 -> 1-2hrs, 3 -> 2-4hrs,  4 -> <4hrs)
#
# StrenSportHours: O quanto tempo no dia você fez exercicios pesados? (1 -> <1hr; 2 -> 1-2hrs, 3 -> 2-4hrs,  4 -> <4hrs)
#
# LeisureHours: Quanto tempo você fica sentado no seu dia a dia? (1 -> <1hr; 2 -> 1-2hrs, 3 -> 2-4hrs,  4 -> <4hrs)
#
# pa1a: ,"Vigorous physical activity did you engage in?" (1 -> <1hr; 2 -> 1-4hrs, 3 -> 5-10hrs,  4 -> <10hrs, 5 -> Dont Know, 6 -> NA)
#
#
# pa7a: ,"Vigorous physical activity did you engage in?" (1 -> <1hr; 2 -> 1-4hrs, 3 -> 5-10hrs,  4 -> <10hrs, 5 -> Dont Know, 6 -> NA)
#
#
# ----------------------------------------------------------------------------------------------
#
# DepressionHx: Você possui depressão? (0 -> Não, 1 -> Sim, 3 -> NA)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
df = pd.read_csv("../data/processed/duracao.csv") \
.drop(["Unnamed: 0", "DepressionHxTrt", "DepressionHxLim"], axis =1)

# %%
df['LightSportHours'].value_counts()
# Out:
# -1.0    20718
#  2.0     3713
#  3.0     2331
#  1.0     1993
#  4.0      628
# Name: LightSportHours, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data=df.corr(),annot=True,)
plt.savefig("../assets/duracao/heatmap_.jpg")
plt.show()

# %%
"""
Criando um histograma comparando com x sem depressão
"""
nao = df.query("DepressionHx == 0")
dep = df.query("DepressionHx == 1")

# %%
df.columns
# Out:
# Index(['LeisureHours', 'WalkHours', 'LightSportHours', 'ModSportHours',
#        'StrenSportHours', 'pa1a', 'pa7a', 'DepressionHx'],
#       dtype='object')

# %%
mob_nao = nao['LeisureHours']
mob_com = dep['LeisureHours']

legenda = {
    1 : '< 1hr',
    2 : '1-2hrs',
    3 : '2-4hrs',
    4 : '>4hrs',
	5 : 'NA',}

plt.hist(mob_nao, bins=range(0, 5,1),
         label='Sem depressão', color='#836FFF', alpha=0.5)
plt.hist(mob_com, bins=range(0, 5,1),
         label='Com depressão', color='#1C1C1C', alpha=0.5)

plt.title('Tempo em que os pacientes fazem atividade sentados')
plt.xlabel('Horas')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,6), [legenda[val] for val in range(1,6)])
plt.savefig("../assets/duracao/LeisureHours-semXcom.jpg")
plt.show()

df['LeisureHours'].value_counts()
# Out:
#  3.0    10508
#  4.0    10125
# -1.0     5308
#  2.0     2940
#  1.0      502
# Name: LeisureHours, dtype: int64

# %%
mob_nao = nao['WalkHours']
mob_com = dep['WalkHours']


legenda = {
    1 : '< 1hr',
    2 : '1-2hrs',
    3 : '2-4hrs',
    4 : '>4hrs',
	5 : 'NA',}
plt.hist(mob_nao, bins=range(0, 5,1),
         label='Sem depressão', color='#836FFF', alpha=0.5)
plt.hist(mob_com, bins=range(0, 5,1),
         label='Com depressão', color='#1C1C1C', alpha=0.5)

plt.title('Tempo em que os pacientes fazem atividade andando')
plt.xlabel('Horas')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,6), [legenda[val] for val in range(1,6)])
plt.savefig("../assets/duracao/WalkHours-semXcom.jpg")
plt.show()

df['WalkHours'].value_counts()
# Out:
#  2.0    8857
#  1.0    8631
# -1.0    7628
#  3.0    3351
#  4.0     916
# Name: WalkHours, dtype: int64

# %%
mob_nao = nao['LightSportHours']
mob_com = dep['LightSportHours']


legenda = {
    1 : '< 1hr',
    2 : '1-2hrs',
    3 : '2-4hrs',
    4 : '>4hrs',
	5 : 'NA',}

plt.hist(mob_nao, bins=range(0, 5,1),
         label='Sem depressão', color='#836FFF', alpha=0.5)
plt.hist(mob_com, bins=range(0, 5,1),
         label='Com depressão', color='#1C1C1C', alpha=0.5)

plt.title('Tempo em que os pacientes fazem atividades leves')
plt.xlabel('Horas')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,6), [legenda[val] for val in range(1,6)])
plt.savefig("../assets/duracao/LightSportHours-semXcom.jpg")
plt.show()

df['LightSportHours'].value_counts()
# Out:
# -1.0    20718
#  2.0     3713
#  3.0     2331
#  1.0     1993
#  4.0      628
# Name: LightSportHours, dtype: int64

# %%
mob_nao = nao['ModSportHours']
mob_com = dep['ModSportHours']


legenda = {
    1 : '< 1hr',
    2 : '1-2hrs',
    3 : '2-4hrs',
    4 : '>4hrs',
	5 : 'NA',}

plt.hist(mob_nao, bins=range(0, 5,1),
         label='Sem depressão', color='#836FFF', alpha=0.5)
plt.hist(mob_com, bins=range(0, 5,1),
         label='Com depressão', color='#1C1C1C', alpha=0.5)

plt.title('Tempo em que os pacientes fazem atividades moderadas')
plt.xlabel('Horas')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,6), [legenda[val] for val in range(1,6)])
plt.savefig("../assets/duracao/ModSportHours-semXcom.jpg")
plt.show()

df['ModSportHours'].value_counts()
# Out:
# -1.0    23904
#  2.0     2652
#  3.0     1271
#  1.0     1215
#  4.0      341
# Name: ModSportHours, dtype: int64

# %%
mob_nao = nao['StrenSportHours']
mob_com = dep['StrenSportHours']


legenda = {
    1 : '< 1hr',
    2 : '1-2hrs',
    3 : '2-4hrs',
    4 : '>4hrs',
	5 : 'NA',}

plt.hist(mob_nao, bins=range(0, 5,1),
         label='Sem depressão', color='#836FFF', alpha=0.5)
plt.hist(mob_com, bins=range(0, 5,1),
         label='Com depressão', color='#1C1C1C', alpha=0.5)

plt.title('Tempo em que os pacientes fazem atividades pesadas')
plt.xlabel('Horas')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,6), [legenda[val] for val in range(1,6)])
plt.savefig("../assets/duracao/StrenSportHours-semXcom.jpg")
plt.show()

df['StrenSportHours'].value_counts()
# Out:
# -1.0    21256
#  2.0     3968
#  1.0     2626
#  3.0     1220
#  4.0      313
# Name: StrenSportHours, dtype: int64

# %%
mob_nao = nao['pa1a']
mob_com = dep['pa1a']


legenda = {
    1 : '< 1hr',
    2 : '1-4hrs',
    3 : '5-10hrs',
    4 : '>10hrs',
	5 : 'Não sabe',
    6: 'NA'}

plt.hist(mob_nao, bins=range(0, 5,1),
         label='Sem depressão', color='#836FFF', alpha=0.5)
plt.hist(mob_com, bins=range(0, 5,1),
         label='Com depressão', color='#1C1C1C', alpha=0.5)

plt.title('Tempo em que os pacientes fazem atividades')
plt.xlabel('Horas por semana')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,7), [legenda[val] for val in range(1,7)])
plt.savefig("../assets/duracao/pa1a-semXcom.jpg")
plt.show()

df['pa1a'].value_counts()
# Out:
# -1.0    28941
#  4.0      119
#  3.0      115
#  2.0      110
#  1.0       66
#  5.0       32
# Name: pa1a, dtype: int64

# %%
mob_nao = nao['pa7a']
mob_com = dep['pa7a']


legenda = {
    1 : '< 1hr',
    2 : '1-4hrs',
    3 : '5-10hrs',
    4 : '>10hrs',
	5 : 'Não sabe',
    6: 'NA'}

plt.hist(mob_nao, bins=range(0, 5,1),
         label='Sem depressão', color='#836FFF', alpha=0.5)
plt.hist(mob_com, bins=range(0, 5,1),
         label='Com depressão', color='#1C1C1C', alpha=0.5)

plt.title('Tempo em que os pacientes fazem atividades')
plt.xlabel('Horas por semana')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,7), [legenda[val] for val in range(1,7)])
plt.savefig("../assets/duracao/pa7a-semXcom.jpg")
plt.show()

df['pa7a'].value_counts()
# Out:
# -1.0    29200
#  1.0       89
#  2.0       65
#  3.0       20
#  4.0        7
#  5.0        1
#  6.0        1
# Name: pa7a, dtype: int64

# %%
# Selecionar as quatro colunas desejadas
colunas = ['LeisureHours', 'WalkHours','LightSportHours', 'ModSportHours', 'StrenSportHours']
cor = ["#40E0D0","#4682B4", '#ADD8E6', '#006400', '#000080']
cor2 = ["#B22222", "#CD5C5C",'#8B008B', '#FA8072', '#FFA500']

legenda = {
    1 : '< 1hr',
    2 : '1-2hrs',
    3 : '2-4hrs',
    4 : '>4hrs',
	5 : 'NA',}

# Plotar o histograma com as quatro colunas
plt.hist(dep[colunas], bins=range(0, 5,1), edgecolor='black', label=colunas, color=cor)
plt.title('Tempo de exercício por hora em pacientes com depressão')
plt.xlabel('Horas')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,6), [legenda[val] for val in range(1,6)])
plt.savefig("../assets/duracao/ativ-com.jpg")
plt.show()

plt.hist(nao[colunas], bins=range(0, 5,1), edgecolor='black', label=colunas, color=cor2)
plt.title('Tempo de exercício por hora em pacientes sem depressão')
plt.xlabel('Horas')
plt.ylabel('Pacientes')
plt.legend( bbox_to_anchor=(1.4,0), loc='lower right')
plt.xticks(range(1,6), [legenda[val] for val in range(1,6)])
plt.savefig("../assets/duracao/ativ-sem.jpg")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29383 entries, 0 to 29382
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LeisureHours     29383 non-null  float64
#  1   WalkHours        29383 non-null  float64
#  2   LightSportHours  29383 non-null  float64
#  3   ModSportHours    29383 non-null  float64
#  4   StrenSportHours  29383 non-null  float64
#  5   pa1a             29383 non-null  float64
#  6   pa7a             29383 non-null  float64
#  7   DepressionHx     29383 non-null  float64
# dtypes: float64(8)
# memory usage: 1.8 MB

# %% [markdown]
# ### Classificador simples

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import pickle

# %%
def report(X_val, y_val, model, name):
    
    print(f"Validação {name}")

    y_pred = model.predict(X_val)

    print(classification_report(y_val, y_pred))


    conf_matrix = confusion_matrix(y_val, y_pred)

    ax = plt.subplot()
    sns.heatmap(conf_matrix, annot = True, ax = ax)

    ax.set_xlabel("Predicted") ; ax.set_ylabel("True");
    ax.set_title("Matriz de confusão")
    
    plt.savefig("../assets/duracao/model"+name+".jpg")
    plt.show()

# %%
df['DepressionHx'].value_counts()
# Out:
# 0.0    15440
# 1.0    13832
# 3.0      111
# Name: DepressionHx, dtype: int64

# %%
df = df.query("DepressionHx != 3")

# %%
X_dados = df.iloc[:, 0:7].values
Y_dados = df.iloc[:, 7].values

# %%
## Separando dados de teste
X_train, X_test, y_train, y_test = train_test_split(X_dados, Y_dados, test_size = 0.2, random_state = 0)

## Separando em validação e treino
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 0)

# %% [markdown]
# #### SVM

# %%
clf = svm.SVC().fit(X_train, y_train)

# %%
report(X_val, y_val, clf, "SVM")
# Out:
# Validação SVM
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.61      0.61      2486
#          1.0       0.55      0.54      0.54      2198
#
#     accuracy                           0.58      4684
#    macro avg       0.57      0.57      0.57      4684
# weighted avg       0.58      0.58      0.58      4684

# %%
filename = '../models/svm-3.sav'
pickle.dump(clf, open(filename, 'wb'))

# %% [markdown]
# ### Regressão Logística

# %%
model = LogisticRegression(multi_class = 'multinomial', solver = 'lbfgs').fit(X_train, y_train)

filename = '../models/rl-3.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
report(X_val, y_val, model, "RL")
# Out:
# Validação RL
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.60      0.60      2486
#          1.0       0.55      0.55      0.55      2198
#
#     accuracy                           0.58      4684
#    macro avg       0.57      0.57      0.57      4684
# weighted avg       0.58      0.58      0.58      4684

# %% [markdown]
# ### KNN

# %%
knn = KNeighborsClassifier().fit(X_train, y_train)

filename = '../models/knn-3.sav'
pickle.dump(knn, open(filename, 'wb'))

# %%
report(X_val, y_val, knn, "knn")
# Out:
# Validação knn
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.74      0.62      2486
#          1.0       0.49      0.27      0.35      2198
#
#     accuracy                           0.52      4684
#    macro avg       0.51      0.51      0.49      4684
# weighted avg       0.51      0.52      0.50      4684

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier().fit(X_train, y_train)

filename = '../models/rf-3.sav'
pickle.dump(rf, open(filename, 'wb'))

# %%
report(X_val, y_val, rf, "rf")
# Out:
# Validação rf
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.50      0.54      2486
#          1.0       0.53      0.63      0.57      2198
#
#     accuracy                           0.56      4684
#    macro avg       0.57      0.56      0.56      4684
# weighted avg       0.57      0.56      0.56      4684
