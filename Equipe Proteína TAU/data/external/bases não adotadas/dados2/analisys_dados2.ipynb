# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset
# Esses dois datasets foram pesquisados também para o tema de Alzheimer, podendo ser encontrado no link https://ctdbase.org/detail.go?type=disease&acc=MESH%3AD003704&view=expStudies.
#
# O "CTD_MESHD003704_exposure_20230520230416.csv" é um dataframe de tamanho mediano, porém no momento de identificar as doenças, por serem diversas tornaria o trabalho muito mais ruidoso no momento de filtrar para pacientes com Alzheimer/Demência, para a quantidade de informações que traria o dataset e seu tamanho, portanto não valeria a pena fazer a análise, pois não seria confiável.

# %%
df = pd.read_csv("CTD_MESHD003704_exposure_20230520230416.csv")

# %%
df
# Out:
#      Reference                             Associated Study Title  \
# 0     24407477  Columbia Center for Children's Environmental H...
# 1     24911217  Northern California Childhood Leukemia Study (...
# 2     22328999                      Diet, Cancer and Health Study
# 3     20585661          Diabetes Incidence Study in Sweden (DISS)
# 4     27384423                    Agricultural Health Study (AHS)
# ..         ...                                                ...
# 188   21708511  Southern California Children's Health Study (CHS)
# 189   21371339                                                NaN
# 190   25487561                                                NaN
# 191   26684294  Exposure Sibling Study (ESS) | Pediatric Envir...
# 192   24528997                                                NaN
#
#                                       Author's Summary  \
# 0    Obese young children may be more likely to dev...
# 1    We found no association with acute lymphoblast...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Reference               193 non-null    int64
#  1   Associated Study Title  99 non-null     object
#  2   Author's Summary        193 non-null    object
#  3   Study Factors           61 non-null     object
#  4   Stressor Agent          193 non-null    object
#  5   Receptors               192 non-null    object
#  6   Country                 192 non-null    object
#  7   Medium                  101 non-null    object
#  8   Exposure Marker         116 non-null    object
#  9   Outcome                 182 non-null    object
#  10  Anatomy                 35 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 16.7+ KB

# %%
df.isna().sum()
# Out:
# Reference                   0
# Associated Study Title     94
# Author's Summary            0
# Study Factors             132
# Stressor Agent              0
# Receptors                   1
# Country                     1
# Medium                     92
# Exposure Marker            77
# Outcome                    11
# Anatomy                   158
# dtype: int64

# %%
df['Outcome'].unique()
# Out:
# array(['Asthma', 'Precursor Cell Lymphoblastic Leukemia-Lymphoma',
#        'Lymphoma, Non-Hodgkin', 'Diabetes Mellitus, Type 1',
#        'Respiratory Sounds|Rhinitis, Allergic',
#        "Agricultural Workers' Diseases|Respiratory Sounds",
#        "Agricultural Workers' Diseases|Asthma",
#        'Asthma|Respiratory Tract Infections',
#        'response to bronchodilator',
#        'negative regulation of respiratory gaseous exchange',
#        'Respiratory Hypersensitivity', 'Respiratory Sounds', nan,
#        'Astrocytoma|Precursor Cell Lymphoblastic Leukemia-Lymphoma|Prenatal Exposure Delayed Effects',
#        'Hypersensitivity|eosinophil homeostasis|IgE immunoglobulin complex, circulating',
#        'negative regulation of inflammatory response|oxylipin biosynthetic process',
#        'T cell activation',
#        'Asthma|Pulmonary Disease, Chronic Obstructive|Respiratory Tract Infections',
#        'respiratory system process',
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Asthma                                                                                                               34
# Precursor Cell Lymphoblastic Leukemia-Lymphoma                                                                        6
# Lymphoma, Non-Hodgkin                                                                                                 5
# Arthritis, Rheumatoid                                                                                                 5
# Multiple Sclerosis                                                                                                    5
#                                                                                                                      ..
# Leukemia|Lymphoma, Non-Hodgkin|Neural Tube Defects                                                                    1
# Bone Neoplasms|Brain Neoplasms|Leukemia|Lymphoma                                                                      1
# ...
